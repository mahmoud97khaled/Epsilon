# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# %%
df= pd.read_excel('output.xlsx')
df
# Out:
#       Last Name   First Name Country  Date of birth Date of birth.1  \
# 0         ZHANG        Yufei     CHN             19             APR
# 1        WATTEL        Marie     FRA              2             JUN
# 2        McKEON         Emma     AUS             24             MAY
# 3    SJOESTROEM        Sarah     SWE             17             AUG
# 4       MACNEIL     Margaret     USA              7             DEC
# ..          ...          ...     ...            ...             ...
# 122   KORSTANJE         Nyls     NED              5             FEB
# 123         SUN       Jiajun     CHN              1             AUG
# 124       SZABO  Szebasztian     HUN             11             MAR
# 125     SHIELDS          Tom     USA             11             JUL
# 126     RAMADAN      Youssef     EGY              7             JUL
#
#      Date of birth.2 Course type    location Gender       Swim  distance(m)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       127 non-null    int64
#  1   Last Name        127 non-null    object
#  2   First Name       127 non-null    object
#  3   Country          127 non-null    object
#  4   Date of birth    127 non-null    int64
#  5   Date of birth.1  127 non-null    object
#  6   Date of birth.2  127 non-null    int64
#  7   Course type      127 non-null    object
#  8   location         127 non-null    object
#  9   Gender           127 non-null    object
#  10  Swim             127 non-null    object
#  11  distance(m)      127 non-null    int64
#  12  25m              0 non-null      float64
#  13  50m              127 non-null    float64
#  14  100m             127 non-null    object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 15.0+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  Date of birth  Date of birth.2  distance(m)  25m  \
# count  127.000000     127.000000       127.000000        127.0  0.0
# mean    63.000000      15.456693      1997.488189        100.0  NaN
# std     36.805797       8.635251         4.017553          0.0  NaN
# min      0.000000       1.000000      1985.000000        100.0  NaN
# 25%     31.500000       9.000000      1995.000000        100.0  NaN
# 50%     63.000000      16.000000      1997.000000        100.0  NaN
# 75%     94.500000      23.000000      2000.000000        100.0  NaN
# max    126.000000      31.000000      2006.000000        100.0  NaN
#
#               50m
# count  127.000000
# mean    26.571732
# std      2.539592
# min     22.520000
# 25%     24.665000
# 50%     26.170000
# 75%     28.300000
# max     31.830000

# %%
df['100m'] = df['100m'].astype(str)
df['100m']=df['100m'].apply(lambda x:x.replace('.',':'))

# %%
df['100m']= pd.to_datetime(df['100m.1'],  format = '%M:%S:%f')

# %%
df['100m'] = pd.Series([val.time() for val in df['100m']])

# %%
df.drop(['100m.1'], axis = 1 , inplace = True)

# %%
# Out:
#       Last Name   First Name Country  Date of birth Date of birth.1  \
# 0         ZHANG        Yufei     CHN             19             APR
# 1        WATTEL        Marie     FRA              2             JUN
# 2        McKEON         Emma     AUS             24             MAY
# 3    SJOESTROEM        Sarah     SWE             17             AUG
# 4       MACNEIL     Margaret     USA              7             DEC
# ..          ...          ...     ...            ...             ...
# 122   KORSTANJE         Nyls     NED              5             FEB
# 123         SUN       Jiajun     CHN              1             AUG
# 124       SZABO  Szebasztian     HUN             11             MAR
# 125     SHIELDS          Tom     USA             11             JUL
# 126     RAMADAN      Youssef     EGY              7             JUL
#
#      Date of birth.2 Course type    location Gender       Swim  distance(m)  \
# ...

# %%
df.
